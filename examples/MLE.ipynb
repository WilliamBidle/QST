# %%
from MLE_Functions import * # the necessary functions to import
# %matplotlib widget

# %% [markdown]
# # Vectorized MLE in Action:

# %%
########################## Important Parameter Declations ################################

dims = 10 # The number of Fock states to consider, including the vacuum state |0>
num_iters = 20 # The number of iterations that will be performed - 20 is good enough

''''''''''''''''''''''''''''''''''''''''''''
''' WORK IN PROGRESS DON'T CHANGE THESE '''
''''''''''''''''''''''''''''''''''''''''''''
include_errors = False
num_err_iters = 5
''''''''''''''''''''''''''''''''''''''''''''
''''''''''''''''''''''''''''''''''''''''''''
''''''''''''''''''''''''''''''''''''''''''''

is_coherent_state = False
show_wigner = True
visualize_steps = False

data_loc = 'data/AT678F_Quadrature_Sim_01_5000.npz'

#################################### Perform MLE #########################################

npzfile = np.load(data_loc)
theta_data, quadrature_data = npzfile['theta'], npzfile['x']

print("The State Under Consideration:")

fig, ax = plt.subplots(figsize = (10, 6))
ax.scatter(theta_data, quadrature_data, s = 2) # plot of quadrature sampling
ax.set_xlabel('Phase', fontsize = 18)
ax.set_ylabel('Quadrature (arb.)', fontsize = 18)
plt.show()

MLE_result = perform_MLE(theta_data, quadrature_data, dims, num_iters, include_errors, num_err_iters, is_coherent_state, show_wigner, visualize_steps)
# Out:
# The State Under Consideration:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# The time to calculate the most likely density matrix was : 15369.631ms
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# The Wigner Distribution:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
